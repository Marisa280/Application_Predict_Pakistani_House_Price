# %% [markdown]
# <a href="https://colab.research.google.com/github/Marisa280/Application_Predict_Pakistani_House_Price/blob/main/applicaton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##OLD

# %%
import tkinter as tk
from tkinter import *

# Creat a new window
instance = Tk()
instance.title("Pakistani Real Estete")
instance.geometry("370x385")
instance.configure(background='#49c5b6')


# Create a new label for the text
label_name = Label(text=" 𝙋𝙖𝙠𝙞𝙨𝙩𝙖𝙣𝙞 𝙍𝙚𝙖𝙡 𝙀𝙨𝙩𝙖𝙩𝙚 ☪ ",fg="#05386b", background='#49c5b6')
label_name.grid(row=0,column=0)

# Create labels for each input field
label1 = tk.Label(text="Property Type :", fg='#05386b', background='#49c5b6')
label2 = tk.Label(text="City :", fg='#05386b', background='#49c5b6')
label3 = tk.Label(text="Province :", fg='#05386b', background='#49c5b6')
label4 = tk.Label(text="Baths Room :", fg='#05386b', background='#49c5b6')
label5 = tk.Label(text="Purpose :", fg='#05386b', background='#49c5b6')
label6 = tk.Label(text="Bedrooms :", fg='#05386b', background='#49c5b6')
label7 = tk.Label(text="Area Type :", fg='#05386b', background='#49c5b6')
label8 = tk.Label(text="Area Size :", fg='#05386b', background='#49c5b6')

# Creat entry fields for each input value
entry1 = tk.Entry()
entry2 = tk.Entry()
entry3 = tk.Entry()
entry4 = tk.Entry()
entry5 = tk.Entry()
entry6 = tk.Entry()
entry7 = tk.Entry()
entry8 = tk.Entry()

# Place the labels and entry fields in the window using a gride layout
label1.grid(row=1, column=0)
entry1.grid(row=1, column=1)
label2.grid(row=2, column=0)
entry2.grid(row=2, column=1)
label3.grid(row=3, column=0)
entry3.grid(row=3, column=1)
label4.grid(row=4, column=0)
entry4.grid(row=4, column=1)
label5.grid(row=5, column=0)
entry5.grid(row=5, column=1)
label6.grid(row=6, column=0)
entry6.grid(row=6, column=1)
label7.grid(row=7, column=0)
entry7.grid(row=7, column=1)
label8.grid(row=8, column=0)
entry8.grid(row=8, column=1)


# Creat a function to calculate the sum of the input values
def calculate():
    x1 = float(entry1.get())
    x2 = float(entry2.get())
    x3 = float(entry3.get())
    x4 = float(entry4.get())
    x5 = float(entry5.get())
    x6 = float(entry6.get())
    x7 = float(entry7.get())
    x8 = float(entry8.get())
    result = 19346358.79261607 + (-974140.23624886 * x1) + (-503124.57291609 * x2) +(-845541.36767927 * x3) + (23491.85569449 * x4) + (-13977945.13611955 * x5) + ( 503152.23747451 * x6) + ( 0 * x7 ) + (1833138.23123343 * x8)
    result = round(result,2)
    result_label.configure(text="Price : " + str(result),fg='#05386b')

# Creat a button to perform the calculation
calculate_button = tk.Button(text="Predict", fg='#05386b',command = calculate)
calculate_button.grid(row=9, column=0, padx=5, pady=5, sticky='nsew')

# Creat a label to display the result
result_label = tk.Label(text="",background='#49c5b6')
result_label.grid(row=9, column=1)

# run the window loop
instance.mainloop()
window.mainloop()

# %%
import tkinter as tk
from tkinter import *

 # Creat a new window
instance = Tk()
instance.title("Pakistani Real Estete")
instance.geometry("370x250")
instance.configure(background='#2F4F4F')


# Create a new label for the text
label_name = Label(text=" Pakistani Real Estete ☪ ",font=('Ahganirya', 15),fg="#FAEBD7", background='#2F4F4F')
label_name.grid(row=0,column=0)

# Create labels for each input field
label1 = tk.Label(text="  Property Type   :", font=('Ahganirya', 10),fg='#FAEBD7', background='#2F4F4F')
label2 = tk.Label(text="  City                 :", font=('Ahganirya', 10), fg='#FAEBD7', background='#2F4F4F')
label3 = tk.Label(text="  Province           :", font=('Ahganirya', 10),fg='#FAEBD7', background='#2F4F4F')
label4 = tk.Label(text="  Baths Room     :", font=('Ahganirya', 10),fg='#FAEBD7', background='#2F4F4F')
label5 = tk.Label(text="  Purpose          :", font=('Ahganirya', 10),fg='#FAEBD7', background='#2F4F4F')
label6 = tk.Label(text="  Bedrooms        :", font=('Ahganirya', 10), fg='#FAEBD7', background='#2F4F4F')
label7 = tk.Label(text="  Area Type        :", font=('Ahganirya', 10),fg='#FAEBD7', background='#2F4F4F')
label8 = tk.Label(text="  Area Size        :", font=('Ahganirya', 10), fg='#FAEBD7', background='#2F4F4F')

# Creat entry fields for each input value
entry1 = tk.Entry()
entry2 = tk.Entry()
entry3 = tk.Entry()
entry4 = tk.Entry()
entry5 = tk.Entry()
entry6 = tk.Entry()
entry7 = tk.Entry()
entry8 = tk.Entry()

# Place the labels and entry fields in the window using a gride layout
label1.grid(row=1, column=0)
entry1.grid(row=1, column=1)
label2.grid(row=2, column=0)
entry2.grid(row=2, column=1)
label3.grid(row=3, column=0)
entry3.grid(row=3, column=1)
label4.grid(row=4, column=0)
entry4.grid(row=4, column=1)
label5.grid(row=5, column=0)
entry5.grid(row=5, column=1)
label6.grid(row=6, column=0)
entry6.grid(row=6, column=1)
label7.grid(row=7, column=0)
entry7.grid(row=7, column=1)
label8.grid(row=8, column=0)
entry8.grid(row=8, column=1)


# Creat a function to calculate the sum of the input values
def calculate():
    x1 = float(entry1.get())
    x2 = float(entry2.get())
    x3 = float(entry3.get())
    x4 = float(entry4.get())
    x5 = float(entry5.get())
    x6 = float(entry6.get())
    x7 = float(entry7.get())
    x8 = float(entry8.get())
    result = 19346358.79261607 + (-974140.23624886 * x1) + (-503124.57291609 * x2) +(-845541.36767927 * x3) + (23491.85569449 * x4) + (-13977945.13611955 * x5) + ( 503152.23747451 * x6) + ( 0 * x7 ) + (1833138.23123343 * x8)
    result = round(result,2)
    result_label.configure(text="Price : " + str(result),fg='#DAA520')

# Creat a button to perform the calculation
calculate_button = tk.Button(text="Predict", fg='#FAEBD7',font= ('',10),command = calculate,background='#DAA520')
calculate_button.grid(row=9, column=0, padx=5, pady=5, sticky='nsew')

# Creat a label to display the result
result_label = tk.Label(text="",background='#2F4F4F')
result_label.grid(row=9, column=1)

# run the window loop
instance.mainloop()
window.mainloop()

# %% [markdown]
# ##NEW

# %%
import tkinter as tk
from tkinter import *

 # Creat a new window
instance = Tk()
instance.title("Pakistani Real Estete")
instance.geometry("370x250")
instance.configure(background='#862633')


# Create a new label for the text
label_name = Label(text=" Pakistani Real Estete ☪ ",font=('Ahganirya', 15),fg="#FAEBD7", background='#862633')
label_name.grid(row=0,column=0)

862633# Create labels for each input field
label1 = tk.Label(text="  Property Type   :", font=('Ahganirya', 10),fg='#FAEBD7', background='#862633')
label2 = tk.Label(text="  City                 :", font=('Ahganirya', 10), fg='#FAEBD7', background='#862633')
label3 = tk.Label(text="  Province           :", font=('Ahganirya', 10),fg='#FAEBD7', background='#862633')
label4 = tk.Label(text="  Baths Room     :", font=('Ahganirya', 10),fg='#FAEBD7', background='#862633')
label5 = tk.Label(text="  Purpose          :", font=('Ahganirya', 10),fg='#FAEBD7', background='#862633')
label6 = tk.Label(text="  Bedrooms        :", font=('Ahganirya', 10), fg='#FAEBD7', background='#862633')
label7 = tk.Label(text="  Area Type        :", font=('Ahganirya', 10),fg='#FAEBD7', background='#862633')
label8 = tk.Label(text="  Area Size        :", font=('Ahganirya', 10), fg='#FAEBD7', background='#862633')

# Creat entry fields for each input value
entry1 = tk.Entry()
entry2 = tk.Entry()
entry3 = tk.Entry()
entry4 = tk.Entry()
entry5 = tk.Entry()
entry6 = tk.Entry()
entry7 = tk.Entry()
entry8 = tk.Entry()

# Place the labels and entry fields in the window using a gride layout
label1.grid(row=1, column=0)
entry1.grid(row=1, column=1)
label2.grid(row=2, column=0)
entry2.grid(row=2, column=1)
label3.grid(row=3, column=0)
entry3.grid(row=3, column=1)
label4.grid(row=4, column=0)
entry4.grid(row=4, column=1)
label5.grid(row=5, column=0)
entry5.grid(row=5, column=1)
label6.grid(row=6, column=0)
entry6.grid(row=6, column=1)
label7.grid(row=7, column=0)
entry7.grid(row=7, column=1)
label8.grid(row=8, column=0)
entry8.grid(row=8, column=1)


# Creat a function to calculate the sum of the input values
def calculate():
    x1 = float(entry1.get())
    x2 = float(entry2.get())
    x3 = float(entry3.get())
    x4 = float(entry4.get())
    x5 = float(entry5.get())
    x6 = float(entry6.get())
    x7 = float(entry7.get())
    x8 = float(entry8.get())
    result = 19346358.79261607 + (-974140.23624886 * x1) + (-503124.57291609 * x2) +(-845541.36767927 * x3) + (23491.85569449 * x4) + (-13977945.13611955 * x5) + ( 503152.23747451 * x6) + ( 0 * x7 ) + (1833138.23123343 * x8)
    result = round(result,2)
    result_label.configure(text="Price : " + str(result),fg='#862633')

# Creat a button to perform the calculation
calculate_button = tk.Button(text="Predict", fg='#862633',font= ('',10),command = calculate,background='#e4d5d3')
calculate_button.grid(row=9, column=0, padx=5, pady=5, sticky='nsew')

# Creat a label to display the result
result_label = tk.Label(text="",background='#e4d5d3')
result_label.grid(row=9, column=1)

# run the window loop
instance.mainloop()
window.mainloop()
